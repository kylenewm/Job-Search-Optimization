# %% [markdown]
# # Introduction

# %% [markdown]
# After reducing the scope of the project, my goal became finding similar job postings to ones I was already interested in as well as clustering job postings so I decipher what actually differentiates the job postings. There is still plenty of work to be done but I did not utilizng the GPU properly and ran out of computing units. Because of this **do not run the models unless you are certain it won't be costly**. I did not have time to do multiprocessing.

# %% [markdown]
# ## Dependency Installation

# %%
# !pip install bertopic[spacy] #for topic modeling with BERT
# !pip install -U spacy #required for data preporcessing 
# !pip install -U spacy[cuda113] #required if running on GPU  
# !pip install -U sentence-transformers #for transforming documents
# !pip install NLTK #for nlp preprocessing

# %%
import spacy
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import re
import string
import math
import sklearn.metrics as metrics
import numpy as np
import random
from sklearn.model_selection import GridSearchCV
spacy.require_gpu()
nlp = spacy.load("en_core_web_sm")
from spacy.lang.en import English
import nltk
from nltk import tokenize, sent_tokenize, word_tokenize, pos_tag
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import pairwise_distances
from sklearn.metrics.pairwise import euclidean_distances
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic

# %%
import json

# %%
def down_nltk():
    nltk.download('wordnet')
    nltk.download('punkt')
    nltk.download('stopwords')
    nltk.download('omw-1.4')
down_nltk()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df= pd.read_csv("job_postings.csv") #reading in file with scraped data

# %%
role1 = df[df['id'] == 'a8c33d35af9e096d'] #Examples of job roles that interests me 
role2 = df[df['id'] == '6ac342c85b839bdc'] #Examples of job roles that interests me 
role3 = df[df['id'] == '00cd478b46b72485'] #Examples of job roles that interests me

# %%
role1
# Out:
#                     id                    company  \
# 1921  a8c33d35af9e096d  Texas Children's Hospital
#
#                                             description     location  \
# 1921  \n \n  \n   \n    \n     We are searching for ...  Houston, TX
#
#                   positionName
# 1921  Associate Data Scientist

# %%
role2
# Out:
#                     id      company  \
# 2450  6ac342c85b839bdc  Wells Fargo
#
#                                             description       location  \
# 2450  \n About this role\n  \n  Wells Fargo is seeki...  Charlotte, NC
#
#                                            positionName
# 2450  2023 Quantitative Analytics Program - Risk Ana...

# %%
role3
# Out:
#                  id   company  \
# 1  00cd478b46b72485  Spectrum
#
#                                          description  \
# 1  \n Company Overview\n  Spectrum’s Product and ...
#
#                      location              positionName
# 1  Maryland Heights, MO 63043  Associate Data Scientist

# %%
X = df['description'] #descriptions for project

# %%
def cleaner(posting): #function for preprocessing all text
    posting = re.sub(r"[^A-Za-z0-9(),!?\'\`]", " ", posting)
    posting = re.sub("^\d+\s|\s\d+\s|\s\d+$", " ", posting)
    posting = re.sub(r"\'s", " \'s", posting)
    posting = re.sub(r"\'ve", " \'ve", posting)
    posting = re.sub(r"n\'t", " n\'t", posting)
    posting = re.sub(r"\'re", " \'re", posting)
    posting = re.sub(r"\'d", " \'d", posting)
    posting = re.sub(r"\'ll", " \'ll", posting)
    posting = re.sub(r",", " , ", posting)
    posting = re.sub(r"!", "", posting)
    posting = re.sub(r"\(", " ", posting)
    posting = re.sub(r"\)", " ", posting)
    posting = re.sub(r"\?", "", posting)
    posting = re.sub(r"\{", " ", posting)
    posting = re.sub(r"\}", " ", posting)
    posting = re.sub(r"\[", " ", posting)
    posting = re.sub(r"\]", " ", posting)
    posting = re.sub(r"\-", "", posting)
    posting = re.sub(r"\_", " ", posting)
    posting = re.sub(r"\s{2,}", " ", posting)
    posting = re.sub(r"[\/,\@,\#,\?,\\,\{,\},\(,\),\[,\],\$,\%,\^,\&,\*,\<,\>]", "", posting)
    posting = re.sub(r'\([^)]*\)', '', posting)
    posting = re.sub('"','', posting)
    posting = re.sub(r"'s\b","",posting)
    posting = re.sub(r"\s+"," ",posting)
    posting = re.sub("[^a-zA-Z0-9]", " ", posting)
    posting = re.sub(r"\b\d+\b", "", posting)
    # posting = re.sub(r"\b[^ai\b", "", posting)
    return posting.strip().lower()

# %%
def cleaning(doc):
    # Lemmatizes and removes stopwords, doc needs to be a spacy 'doc'
    txt = [token.lemma_ for token in doc if not token.is_stop]
    return ' '.join(txt)

# %%
cleaner_postings =  [cleaner(posting) for posting in X]

# %%
lem_postings = [cleaning(doc) for doc in nlp.pipe(cleaner_postings, batch_size=10)] #do NOT run on local cpu, will crash or reduce batch size

# %%
# drop na
cleaned_postings = pd.Series(lem_postings).dropna().tolist()

# %%
tfidf = TfidfVectorizer() 
transformed = tfidf.fit_transform(cleaned_postings)

# %%
from sklearn.metrics.pairwise import cosine_similarity
def top_n_similarities(n, num_postings, all_postings, interested_post_index):
  max_sims = [0 for i in range(n)]
  ind = [None for i in range(n)]
  counter = 0
  for i in range(num_postings):
    sim = cosine_similarity(all_postings[interested_post_index], all_postings[i]) 
    if counter < n and i != interested_post_index :
      max_sims[counter] = sim
      ind[counter] = i 
      counter += 1
    elif sim > min(max_sims) and  i != interested_post_index:
      index_replaced = max_sims.index(min(max_sims))
      max_sims[index_replaced] = sim
      ind[index_replaced] = i
  return max_sims, ind
arr1, ind1 = top_n_similarities(5, len(cleaned_postings), transformed, 1921)

# %%
arr2, ind2 = top_n_similarities(5, len(cleaned_postings), transformed, 1)

# %%
arr3, ind3 = top_n_similarities(5, len(cleaned_postings), transformed, 2450)

# %%
# Out:
# [24, 543, 885, 2467, 2566]

# %% [markdown]
# Below I took the 5 most similar roles for each of the 3 job postings from above. As can be seen some of the job postings are nearly idenitcal (besides location).

# %%
arr_f = np.array([ind1,ind2,ind3]).flatten()
arr_f
df.iloc[arr_f].head(15)
# Out:
#                     id                         company  \
# 217   4fe36d447c97f9ef    Riverside Community Hospital
# 2319  3d2b5321d26cf677          NYC Health + Hospitals
# 1987  c7309a62faa7e335                 Rice University
# 2455  6b2a70dad40403c1            Children's Wisconsin
# 2747  d062ee5698f36632  Nationwide Children's Hospital
# 1932  ae925abd90289edf                Home Depot / THD
# 1766  6f0dc52c68402ea4                        Spectrum
# 2708  c1d100eaadd1adf2                            Vaco
# 2697  bf4067ea1645a274                            Octo
# 2529  88e22f89fca867f0   AllianceRx Walgreens Pharmacy
# 24    0b3cb69b7f2722b3                WELLS FARGO BANK
# 543   c6752fe929483f67                WELLS FARGO BANK
# 885   3a04a1b9a726068f                WELLS FARGO BANK
# 2467  6fb578af3013eb71                WELLS FARGO BANK
# 2566  965aed89bc0e79d1                WELLS FARGO BANK
#
#                                             description  \
# 217   \n Description SHIFT: No Weekends\n  SCHEDULE:...
# 2319  About NYC Health + Hospitals\nIn its century o...
# 1987  \n ***This position requisition requires a cov...
# 2455  \n \n  \n   Organizational Information\n   \n ...
# 2747  The Data Analyst for Children's Community Prac...
# 1932  \n \n  Position Purpose:\n   The Associate Dat...
# 1766  JOB SUMMARY This position is responsible for a...
# 2708  \n Position Purpose:\n  The Data Scientist is ...
# 2697  \n As a Data Analyst at Octo, you will interac...
# 2529  \n \n  \n   \n    Job Level\n   \n   \n     Se...
# 24    \n At Wells Fargo, we are looking for talented...
# 543   \n At Wells Fargo, we are looking for talented...
# 885   \n Data Management and Insights (DMI) is trans...
# 2467  \n At Wells Fargo, we are looking for talented...
# 2566  \n At Wells Fargo, we are looking for talented...
#
#                         location  \
# 217          Riverside, CA 92501
# 2319          Brooklyn, NY 11235
# 1987                 Houston, TX
# 2455               Milwaukee, WI
# 2747          Columbus, OH 43205
# 1932           Atlanta, GA 30301
# 1766  Maryland Heights, MO 63043
# 2708                 Atlanta, GA
# 2697            Reston, VA 20191
# 2529                     Florida
# 24                    Dallas, TX
# 543            San Francisco, CA
# 885                  Addison, TX
# 2467        Saint Louis Park, MN
# 2566   West Des Moines, IA 50265
#
#                                            positionName
# 217                         Maternal Child Data Analyst
# 2319  Clinical Business Analyst Level II - Data Analyst
# 1987                                       Data Analyst
# 2455                         Technical Business Analyst
# 2747      Data Analyst - Children's Community Practices
# 1932       Associate Data Scientist, Decision Analytics
# 1766                           Data & Reporting Analyst
# 2708               Data Scientist (Remote)- $120k-$130k
# 2697                                       Data Analyst
# 2529                 Sr Analyst Data & Decision Science
# 24    2023 Wells Fargo Analytics & Data Analyst Program
# 543   2023 Wells Fargo Analytics & Data Analyst Program
# 885   Business Execution Consultant - Enterprise Ana...
# 2467                          Lead Analytics Consultant
# 2566                          Lead Analytics Consultant

# %% [markdown]
# ## With Transformers

# %% [markdown]
# ### Document Similairty

# %%
from sentence_transformers.cross_encoder import CrossEncoder
import numpy as np

# %%
model = CrossEncoder('cross-encoder/stsb-distilroberta-base')

# %%
target_post = cleaned_postings[2450]
sentence_combinations = [[target_post, posting] for posting in cleaned_postings]
similarity_scores = model.predict(sentence_combinations)

# %%
sim_scores_argsort = (np.argsort(similarity_scores)[::-1][0:10])

print("Top 5 Scores")
for idx in sim_scores_argsort:
    print(f"Similarity: {similarity_scores[idx]}, {idx}")
# Out:
# Top 5 Scores
# Similarity: 0.8582262396812439, 2450
# Similarity: 0.8379937410354614, 1713
# Similarity: 0.8198832869529724, 275
# Similarity: 0.8162440061569214, 1366
# Similarity: 0.8152064681053162, 750
# Similarity: 0.8145310878753662, 1488
# Similarity: 0.8135110139846802, 265
# Similarity: 0.810581386089325, 1252
# Similarity: 0.8082534670829773, 2579
# Similarity: 0.8081510663032532, 1035

# %%
df.iloc[sim_scores_argsort].head(10)
# Out:
#                     id                     company  \
# 2450  6ac342c85b839bdc                 Wells Fargo
# 1713  5d221ffeda0004db                       Crowe
# 275   673605c177da5c8c       Mather Economics, LLC
# 1366  e14107e49e5b1934                 Xometry Inc
# 750   109c579c6d5aa45e        Alcor Solutions Inc.
# 1488  09d3c2bde4951d72        City of Pasadena, CA
# 265   63af9bde1d75919e    Liberty Mutual Insurance
# 1252  bb5cf958e710d1f4  Teleqo Technical Solutions
# 2579  9b7ae38ac4932da1            WELLS FARGO BANK
# 1035  69c8a55495385244                       Wacom
#
#                                             description            location  \
# 2450  \n About this role\n  \n  Wells Fargo is seeki...       Charlotte, NC
# 1713  \n Your Journey at Crowe Starts Here:\n \n  At...   Chicago, IL 60606
# 275   \n Mather Economics seeks new graduates to ear...         Atlanta, GA
# 1366  \n \n  \n   Xometry (NASDAQ: XMTR) powers the ...       United States
# 750   Alcor Solutions is hiring a Senior ServiceNow ...              Remote
# 1488  \n\n \n  \n   The City of Pasadena is seeking ...        Pasadena, CA
# 265   \n \n  Why you may enjoy working at Solaria La...    Boston, MA 02116
# 1252  Machine Learning Engineer\nDescription\nTeleqo...              Remote
# 2579  \n About this role:\n  \n  Wells Fargo is seek...           Tempe, AZ
# 1035  \n Wacom is seeking an IT Business Analyst to ...  Portland, OR 97209
#
#                                            positionName
# 2450  2023 Quantitative Analytics Program - Risk Ana...
# 1713    Machine Learning DevOps Infrastructure Engineer
# 275                        Data Science Analyst I or II
# 1366          Product Data Scientist, Supplier Services
# 750                  Senior ServiceNow Business Analyst
# 1488  Utility Safety Coordinator (Management Analyst...
# 265   Solaria Labs Data Science Co-op (January - Jun...
# 1252                          Machine Learning Engineer
# 2579  Senior Business Execution Consultant - Technol...
# 1035                     IT Business Analyst- eCommerce

# %%
print(ind3) #5 most similar from cosine similarity with data preporcessing
# Out:
# [24, 543, 885, 2467, 2566]

# %% [markdown]
# There is a large variation between the document similarity outputs when using the cross encoder versus data preprocessing with cossine similarity and TFIDF. There is no way of measuring which solution is better without the target variable to it is left to user disccretion which one is preferred (if goal is stil job optimization).

# %% [markdown]
# ### Topic Modeling

# %% [markdown]
# Greate article for helping with topic modeling BERT:
# https://towardsdatascience.com/topic-modeling-with-bert-779f7db187e6

# %%
# !pip install bertopic
# !pip install --upgrade joblib==1.1.0 #must use older version to fix dependency issue with HDBSCAN
from bertopic import BERTopic

# %% [markdown]
# ### First Model and Visualization Walk through

# %%
from bertopic import BERTopic
from transformers.pipelines import pipeline
embedding_model = pipeline("feature-extraction", model="distilbert-base-cased")
topic_model = BERTopic(embedding_model=embedding_model, top_n_words=20, diversity = 0.2) #diversity score calculated t for non-diverse words
topics, probs = topic_model.fit_transform(df['description'][0:100])
# Out:
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertModel: ['vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
topic_model.get_topic(0)
# Out:
# [('data', 0.049183094742091316),
#  ('for', 0.037578836885833876),
#  ('or', 0.03519739286610825),
#  ('our', 0.029571865484904262),
#  ('experience', 0.02780653297077208),
#  ('we', 0.02719359747040182),
#  ('business', 0.02570125241618582),
#  ('work', 0.02180218137799408),
#  ('are', 0.021617272685283292),
#  ('on', 0.02039490373370273),
#  ('will', 0.020345655784718825),
#  ('that', 0.020126904209023515),
#  ('you', 0.01925949472423696),
#  ('an', 0.01843832087678641),
#  ('team', 0.017769810430232146),
#  ('skills', 0.017625177444212617),
#  ('management', 0.01686824047940142),
#  ('all', 0.016565778360258833),
#  ('ability', 0.015184061148515816),
#  ('at', 0.015165881151907142)]

# %%
topic_model.visualize_documents(df['description'][0:100])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6fd8a588-584e-4adb-afce-c2578d21ea86" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fd8a588-584e-4adb-afce-c2578d21ea86")) {                    Plotly.newPlot(                        "6fd8a588-584e-4adb-afce-c2578d21ea86",                        [{"hoverinfo":"text","hovertext":["1. Provide technical assistance to Participating Agencies and Service Providers in the use of HMIS\n2. Develop standard reports and queries on HMIS usage and data for interested parties\n3. Run regular data quality reports including but not limited to missing data and follow ups\n4. Work with HMIS Staff and Executive Director to interpret and maintain confidentiality and quality of data\n5. Work with agency leaders to compile and/or review all required reports for funders as needed\n6. Work to report monthly and as needed on program results to executive director and board of directors as needed\n7. Oversee Data Entry for Agencies using HMIS\n8. Ensure participating agencies\u2019 HMIS utilization through reporting\n9. Work with Director of Data Systems to develop HMIS user surveys to ensure data quality and relevant training\n10. Monitor and evaluate the quality, timeliness, and accuracy of data input and reporting\n11. Build and export reports into various reporting software\n12. Assist in the generation and submission of program and community-level reports from the HMIS (LSA, SPM, PIT & HIC)\n13. Oversight of all data elements in HMIS as set out by the HUD Data Standards\n14. Responsible for ensuring universal data elements and Bed Inventory for any agency listed on the Housing Inventory Chart\n15. Coordinate and monitor all changes to the database resulting from revisions to the HMIS data standards\n16. Work closely with Participating Agencies to clean up data issues, and improve data quality\n17. Integrate the needs of new programs (e.g. ESG RRH) in HMIS for data collection and reporting, and develop new data entry and reporting protocols\n18. Performs other duties as directed\nJob Type: Full-time\nPay: $16.38 per hour\nBenefits:\n\n Dental insurance\n Health insurance\n Life insurance\n Paid time off\n Retirement plan\n Vision insurance\n\nSchedule:\n\n 8 hour shift\n Monday to Friday\n\nEducation:\n\n Associate (Preferred)\n\nExperience:\n\n Microsoft Excel: 1 year (Preferred)\n\nWork Location: One location","TechPoint LLC is a technology driven IT Staffing and Consulting company. We are actively looking for fresh talent: Business, Economics, Computer Science or IT related field who have recently graduated.\nWith immediate demand in our client space, we are currently seeking qualified individuals for Business Analyst roles. We also provide training to the right candidate for the role. At TechPoint, our classes are designed to be highly interactive and are taught by seasoned experts and industry experienced instructors. Our training sessions provide advanced topics, industry best practices and tips in a Flexible Format. We take full pride in knowledge share, provide you with all tools access and technology guidance to improve your technical standards. You will participate in group discussions, workshops, lessons to practice and shared information in the class.\nTopic covered:\n\n Introduction to SDLC\n Business Analyst Fundamentals in SDLC\n Business Analyst Need Assessments\n Business Planning & Monitoring\n Requirement Elicitation\n Requirement Analysis & Management\n Testing, Defects & UAT\n Agile BA with Storyboarding\n Visual Studio for UML\n Agile Project Management\n MS Excel for Data Mapping\n\nEligibility: \n\n We are actively looking for fresh talent: Business, Economics, Computer Science or IT related field\n Location: All around US, and c ...

# %% [markdown]
# Stop words clearly need to be removed since they do not provide much value for isolating the different documents.

# %% [markdown]
# ### Secodn Model and Visualization Walkthrough

# %% [markdown]
# I need to reduce the dimensionality of the data so the distance metrics with DBSAN will be effective.

# %%
from umap import UMAP
posts = df['description'].values
sentence_model = SentenceTransformer('distilbert-base-nli-mean-tokens')
embeddings = sentence_model.encode(posts, show_progress_bar=True)
# Out:
# Downloading:   0%|          | 0.00/265M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/450 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Batches:   0%|          | 0/91 [00:00<?, ?it/s]

# %%
umap_embeddings = UMAP(n_neighbors=15, 
                            n_components=2, #needs to be 2 for graph to work 
                            metric='cosine').fit_transform(embeddings)

# %% [markdown]
# https://hdbscan.readthedocs.io/en/latest/how_hdbscan_works.html
# HDBSCAN is less sensitive to noise than DBSCAN so we will using this clustering algorithm instead. Above is the documentation which i found helpful.

# %% [markdown]
# I used 'leaf' for clustering selection method instead of 'eom' to allow for more clusters. I then fined tuned other paramaters such as min_cluster size to help increase cluster density. Also HDBSCAN allows for values to be outlier and as a result not all postings need to be assigned to a cluster (as can be seen in the graph below).

# %%
from hdbscan import HDBSCAN
cluster = HDBSCAN(min_cluster_size=40, 
                          metric='euclidean',                      
                          cluster_selection_method='leaf').fit(umap_embeddings)

# %%
import seaborn as sns
color_palette = sns.color_palette('Paired', 100) #add more colors to prevent index error in next steps 
cluster_colors = [color_palette[x] if x >= 0 else (0.5, 0.5, 0.5) for x in cluster.labels_]
cluster_member_colors = [sns.desaturate(x, p) for x, p in
                         zip(cluster_colors, cluster.probabilities_)]
plt.scatter(*umap_embeddings.T, s=50, linewidth=0, c=cluster_member_colors, alpha=0.75)
plt.xlim(7.5, 17.5)
plt.ylim(6,13)
plt.rcParams["figure.figsize"] = (10,10)
plt.rcParams['axes.titlesize'] = 20
plt.title("Hierarchical Density Based Clustering")
plt.show()

# %%
vectorizer = TfidfVectorizer(stop_words = 'english')
embeddings = sentence_model.encode(posts, show_progress_bar=False)
bert1 = BERTopic(hdbscan_model = cluster, language = "english", vectorizer_model = vectorizer)

# %%
topics, probs = bert1.fit_transform(posts,embeddings)

# %%
bert1.get_topic_info().head(5)
# Out:
#    Topic  Count                                     Name
# 0     -1   1558         -1_data_experience_work_business
# 1      0    362          0_data_experience_work_position
# 2      1    354  1_business_data_experience_requirements
# 3      2    194          2_data_business_experience_work
# 4      3    184          3_data_business_experience_work

# %%
bert1.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c5a26d7e-08ed-43ab-a876-91c9e07a573e" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5a26d7e-08ed-43ab-a876-91c9e07a573e")) {                    Plotly.newPlot(                        "c5a26d7e-08ed-43ab-a876-91c9e07a573e",                        [{"coloraxis":"coloraxis","name":"0","x":["0_data_experience_work","1_business_data_experience","2_data_business_experience","3_data_business_experience","4_data_experience_health","5_data_health_experience"],"y":["0_data_experience_work","1_business_data_experience","2_data_business_experience","3_data_business_experience","4_data_experience_health","5_data_health_experience"],"z":[[1.0000000000000406,0.8917297370135974,0.9081135208851628,0.9362716260694728,0.9424069845766432,0.8931293101881115],[0.8917297370135974,1.0000000000000515,0.9121837606237663,0.8475931743271155,0.8211400472586029,0.8249340922320535],[0.9081135208851628,0.9121837606237663,1.0000000000000606,0.8704727247460321,0.8564066558454599,0.8192460627669961],[0.9362716260694728,0.8475931743271155,0.8704727247460321,0.9999999999999784,0.9126813854156735,0.8558935132749892],[0.9424069845766432,0.8211400472586029,0.8564066558454599,0.9126813854156735,0.9999999999999976,0.8503193004830951],[0.8931293101881115,0.8249340922320535,0.8192460627669961,0.8558935132749892,0.8503193004830951,0.9999999999999702]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>Similarity Score: %{z}<extra></extra>"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555 ...

# %% [markdown]
# As we can see form above the topics did not separate as well as I would have like. In the future I will spend more time on preoprocessing and creating customized transformers.

# %%
bert1.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cc207374-ad00-4e11-b3d4-3292296a09d8" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc207374-ad00-4e11-b3d4-3292296a09d8")) {                    Plotly.newPlot(                        "cc207374-ad00-4e11-b3d4-3292296a09d8",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.02084195230916928,0.021948820174320247,0.025696634049210736,0.02707753647759855,0.03127035082149174],"y":["required  ","position  ","work  ","experience  ","data  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.02250292961472247,0.025158908819275978,0.030879358918508893,0.03630344760731866,0.03789437188159344],"y":["work  ","requirements  ","experience  ","data  ","business  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.01802527898867679,0.02165343930264073,0.02200613153366018,0.027752106796389033,0.03448328784046286],"y":["team  ","work  ","experience  ","business  ","data  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.020895502010808347,0.02424119515773845,0.02718504109573705,0.027944640285499252,0.0399442541314357],"y":["team  ","work  ","experience  ","business  ","data  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.01818709526329441,0.02242154729672179,0.024853164907301366,0.027511195094663723,0.04256965056034686],"y":["research  ","work  ","health  ","experience  ","data  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.02079693124257764,0.02418870069412528,0.027179499652806974,0.03802874752927998,0.05269331181564183],"y":["required  ","information  ","experience  ","health  ","data  "],"type":"bar","xaxis":"x6","yaxis":"y6"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"# ...

# %% [markdown]
# As can be seen from above there is a lot of work to be done with the top modeling. At a later date I will not allow words that are very common like (data, experience, required, and work).

# %% [markdown]
# Here is a great link that helped with understanding UMAP:
# https://umap-learn.readthedocs.io/en/latest/parameters.html

# %% [markdown]
# # Conclusion

# %% [markdown]
# I was extremely naive with my initial scope of the project. Trying to create method to accurately classify new job postings was insane. I probably spent 50+ hours before giving up on this. After giving up, I tried to just classify on labels I created myself. I once again spent hours longer tring to do this. I tried reducing the scope again to gain a good sihloutte score for topic modeling. Unfortunately, I did not have the knowledge within NLP to do the data preprocessing. Even are receiving assistance, I realized clustering documents of the size I was working with was unrealistic. I tried using HuggingFace to help with implementation with new project ideas such as using zero-shot classification. However, the run time was way to slow.
#
# Prior to all of this taking place, I got a 14-day free trial to datbricks to try learning a new tool and gain exposure to data engineering. I however failed with this as well by pricing out of the AWS free tier.
#
# Clustering was unsuccessful as well after many hours and I resorted to just a table of similarity metrics with 10 randomly selected documents.
#
# There were many more failures throughout the duration of the project but I learned a very important lesson to be okay with imperfection. In the near future I will have a more detailed discussions,preprocessing, and modeling.

# %% [markdown]
# I was very happy to atleast be able to graph some  noticebale differences between some of the documents with HDBSCAn. I was unfamiliar with this technique before the assignment. I was also surprised how easy the concepts of transformers, encoders, and other new concepts were to pick up. I hope to expand on this knowledge in the near future.
